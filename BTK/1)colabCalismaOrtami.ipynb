# %% [markdown]
# # Google Colab Çalışma Ortamı

# %% [markdown]
# ## Merhaba

# %%
print('hello world')
# Out:
# hello world

# %%
bir_gunde_saniye_sayisi = 24 * 60 * 60 
bir_gunde_saniye_sayisi
# Out:
# 86400

# %% [markdown]
# ## CPU Hakkında

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: AuthenticAMD
# cpu family	: 23
# model		: 49
# model name	: AMD EPYC 7B12
# stepping	: 0
# microcode	: 0x1000065
# cpu MHz		: 2249.998
# cache size	: 512 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# bugs		: sysret_ss_attrs spectre_v1 spectre_v2 spec_store_bypass
# bogomips	: 4499.99
# TLB size	: 3072 4K pages
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 48 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: AuthenticAMD
# cpu family	: 23
# model		: 49
# model name	: AMD EPYC 7B12
# stepping	: 0
# microcode	: 0x1000065
# cpu MHz		: 2249.998
# cache size	: 512 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# bugs		: sysret_ss_attrs spectre_v1 spectre_v2 spec_store_bypass
# bogomips	: 4499.99
# TLB size	: 3072 4K pages
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 48 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ### RAM Hakkında

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13333556 kB
# MemFree:        10711140 kB
# MemAvailable:   12505348 kB
# Buffers:           72408 kB
# Cached:          1874240 kB
# SwapCached:            0 kB
# Active:           698476 kB
# Inactive:        1674340 kB
# Active(anon):     399428 kB
# Inactive(anon):      312 kB
# Active(file):     299048 kB
# Inactive(file):  1674028 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               320 kB
# Writeback:             0 kB
# AnonPages:        426160 kB
# Mapped:           222452 kB
# Shmem:               924 kB
# Slab:             160848 kB
# SReclaimable:     124060 kB
# SUnreclaim:        36788 kB
# KernelStack:        3504 kB
# PageTables:         5308 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666776 kB
# Committed_AS:    2524280 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# Percpu:              928 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:       76988 kB
# DirectMap2M:     6213632 kB
# DirectMap1G:     9437184 kB

# %% [markdown]
# # Veri Bilimi
#
# Veri bilimi için `python`'ın farklı kütüphanelerini colab ortamında kullanarak analiz ve görselleştirme işlemleri de yapabiliriz.
#
# `Numpy` ve `Matplotlib` kütüphanelerini kullanarak bir görselleştirme yapalım !

# %%
import numpy as np
from matplotlib import pyplot as plt

ys= 50 + np.random.randn(50)
x= [x for x in range ( len(ys) )]

plt.plot(x, ys, '*')
plt.fill_between(x, ys, 45, where = (ys>45), facecolor = 'm', alpha=0.5)

plt.title('Örnek Gösterim')
plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
# !ls
# Out:
# 'My Drive'

# %%
# !ls "/gdrive/My Drive/calisma_ortami/"
# Out:
# app.py	colabCalismaOrtami.ipynb

# %%
import os
os.chdir("/gdrive/My Drive/calisma_ortami/")
# !ls
# Out:
# app.py	colabCalismaOrtami.ipynb

# %% [markdown]
# ##Kütüphane Kurulumları

# %%
# !pip install -q keras
import keras
# Out:
# Using TensorFlow backend.

# %%
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %% [markdown]
# ##GPU Özelliklerinin Görüntülenmesi

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow_hub as hub

# %%
print("TF Version:", tf.__version__)
print("Hub Version:",hub.__version__)
print("GPU is","Available" if tf.test.is_gpu_available() else "Not Available")
# Out:
# TF Version: 2.2.0
# Hub Version: 0.8.0
# WARNING:tensorflow:From <ipython-input-4-827d5a69a4ef>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU is Available

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16206567397289857512, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17508514285138568466
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 339951016250974123
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14648777152
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11399923692173972803
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %%
# !python3 app.py  # drive da bulunan bir py dosyasının çalıştırılması
# Out:
# 2020-07-20 18:48:43.213468: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Traceback (most recent call last):
#   File "app.py", line 7, in <module>
#     from tensorflow.examples.tutorials.mnist import input_data
# ModuleNotFoundError: No module named 'tensorflow.examples.tutorials'

# %%
# !ls
# Out:
# app.py	colabCalismaOrtami.ipynb

# %%
# !kill -9 -1  #sanal makinaya restart atıyor
