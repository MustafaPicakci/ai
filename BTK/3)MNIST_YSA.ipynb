# %% [markdown]
# # MNIST veri kümesini kullanarak yapay sinir ağları ile  rakam sınıflandırma

# %%
from keras.datasets import mnist

(train_images,train_labels), (test_images,test_labels)=mnist.load_data()

# %% [markdown]
# ## MNIST Veri kümesinin yüklenmesi

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_images)
# Out:
# 60000

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# ##Yapay Sinir Ağı Mimarisi

# %%
from keras import models
from keras import layers

# %%
network=models.Sequential() #boş model oluşturuyoruz
network.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(10,activation='softmax'))

# %% [markdown]
# ##YSA Modelinin Derlenmesi

# %%
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %% [markdown]
# ##Girişlerin Ve Etikletlerin Hazırlanması

# %%
train_images=train_images.reshape((60000,28*28))
train_images=train_images.astype('float32') / 255

test_images=test_images.reshape((10000,28*28))
test_images=test_images.astype('float32') / 255

# %%
from keras.utils import to_categorical

train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)

# %% [markdown]
# ##YSA Modelinin Eğitilmesi

# %%
network.fit(train_images,train_labels,epochs=5,batch_size=128)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 3s 58us/step - loss: 0.2578 - accuracy: 0.9244
# Epoch 2/5
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1036 - accuracy: 0.9693
# Epoch 3/5
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0691 - accuracy: 0.9794
# Epoch 4/5
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0499 - accuracy: 0.9848
# Epoch 5/5
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0380 - accuracy: 0.9886

# %%
test_loss,test_acc=network.evaluate(test_images,test_labels)
# Out:
# 10000/10000 [==============================] - 1s 74us/step

# %%
print('test_loss:',test_loss)
# Out:
# test_loss: 0.06819952556586359

# %%
print('test_acc:',test_acc)
# Out:
# test_acc: 0.9789000153541565
